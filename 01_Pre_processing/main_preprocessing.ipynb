# %%
import glob
import os
from raster_to_dataframe import raster_to_dataframe

raster_folder = r"C:\Users\varun\Downloads\Data_img_2021\Data_img_2021_ndsi_hillshade"
landcover_tif_path = r"C:\Varun\Clark\Code\Random Forest\Data\Land_cover/modis_landcover_2020_pnw_aligned_full_extent.tif"
output_csv_path = r"C:\Varun\Clark\test/output_combined.csv"

raster_to_dataframe(raster_folder, landcover_tif_path, output_csv_path)
# Out:
# Combined data saved to: C:\Varun\Clark\test/output_combined.csv
